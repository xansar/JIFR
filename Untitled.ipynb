# %%
# !python run_SVDPP.py
# Out:
# =============read process inverted list==============
# =============read process inverted list==============
# =============read process inverted list==============
# ==========Config==========
# TRAIN:
# 	epoch: 150
# 	device: cuda
# 	log_pth: ./log/
# 	save_pth: ./save/
# 	random_seed: 4565
# 	mode: debug
# 	eval_step: 5
# 	warm_epoch: 25
# 	task: Rate
# OPTIM:
# 	optimizer: AdamW
# 	lr_scheduler: CosineAnnealingWarmRestarts
# 	lr_adapt_step: 10
# 	learning_rate: 1e-2
# 	weight_decay: 0
# 	lamda: 5e-4
# 	lamda_t: 5e-4
# LOSS:
# 	loss_name: TrustSVDLoss
# MODEL:
# 	model_name: SVDPP
# 	pred_user_num: 1598
# 	total_user_num: 19790
# 	item_num: 24985
# 	embedding_size: 10
# 	global_bias: 4.89
# 	num_sample: 20
# DATA:
# 	data_name: ExtendedEpinions
# 	train_batch_size: 2048
# 	val_batch_size: 2048
# 	test_batch_size: 2048
# 	num_workers: 7
# 	neg_num: 100
# METRIC:
# 	ks: [3, 5, 10]
# 	metric_name: ['HR']
# ...
#
# ==========TRAIN BEGIN==========
# ...
